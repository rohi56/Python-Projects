# %% [markdown]
# # Introduction

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = np.arange(10)
y = np.arange(0, 1000, 100)

plt.plot(x, y)

# %%
x = np.random.normal(0.5, 0.1, (100))
x.sort()
y = x **2
print(x)
print(y)
plt.plot(x, y)
# Out:
# [0.19982838 0.31800569 0.32661946 0.34189028 0.3474956  0.35194712
#  0.35540694 0.37388709 0.38200165 0.38480136 0.38667307 0.39077507
#  0.39385422 0.39416635 0.40190104 0.40275944 0.40703921 0.40831988
#  0.41372175 0.41641988 0.4164302  0.41670628 0.41968402 0.42035475
#  0.42070654 0.43166272 0.43198717 0.43288212 0.43549438 0.43711512
#  0.44337061 0.44351256 0.4437558  0.4446392  0.44543967 0.4485691
#  0.45210921 0.45627185 0.45848276 0.45894774 0.45921245 0.46001074
#  0.47318606 0.47849772 0.47998881 0.48027661 0.48117485 0.48311926
#  0.4866186  0.48791244 0.49676195 0.49821668 0.5115249  0.51156315
#  0.51159571 0.5125597  0.51421922 0.51788649 0.51841381 0.52008275
#  0.52079716 0.52565207 0.52874674 0.53117716 0.53377316 0.53566237
#  0.53782653 0.53841915 0.54107672 0.54176072 0.54242478 0.54702599
#  0.55109507 0.5516091  0.55367719 0.56113508 0.56520834 0.56621241
#  0.57419258 0.57650897 0.57992077 0.5849161  0.58586372 0.58624896
# ...

# %%
plt.plot(x, y, 'o')

# %%
x = np.arange(100)
y = x**3
plt.plot(y, '1')

# %%
markers = ['o', '*', '.', ',', 'x', 'X', '+', 'P', 's', 'D', 'd', 'p', 'H', 'h', 'v', '^', '<', '>', '1', '2', '3', '4', '|', '_']

for m in markers:
  print(m)
  plt.plot(y, m)
  plt.show()
# Out:
# o
# *
# .
# ,
# x
# X
# +
# P
# s
# D
# d
# p
# H
# h
# v
# ^
# <
# >
# 1
# 2
# 3
# 4
# |
# _

# %%
y = np.array([1, 3, 13])
line = ['-',':','--','-.']
for l in line:
  print(l)
  l = 'o' + l + 'r'
  plt.plot(y, l)
  plt.show()
# Out:
# -
# :
# --
# -.

# %%
color = ['r','g','b','c','m','y','k','w']
for c in color:
  print(c)
  c = 'o:' + c
  plt.plot(y, c)
  plt.show()
# Out:
# r
# g
# b
# c
# m
# y
# k
# w

# %%
plt.plot(y, marker = '^', ms = 30)

# %%
x = np.arange(10)
y1 = x*2
y2 = x**2
plt.plot(y1)
plt.plot(y2)

# %%
plt.plot(x, y1)
plt.plot(x, y2)

# %%
plt.plot(x, y1, label = 'double')
plt.plot(x, y2, label = 'square')
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.grid()
plt.legend(['1st', '2nd'])

# %%
plt.subplot(2, 1, 1)
plt.plot(x, y1, label = 'double')
plt.legend()
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.subplot(2, 1, 2)
plt.plot(x, y2, label = 'square')
plt.legend()
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.grid()

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y1, label = 'double')
plt.legend()
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.subplot(1, 2, 2)
plt.plot(x, y2, label = 'square')
plt.legend()
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.grid()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.plot(x, y, 'o')

# %%
plt.scatter(x, y)

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='hot')

plt.colorbar()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

# %%
plt.scatter(x, y, c = colors, cmap = 'hot', alpha = 0.5, s = sizes)
plt.colorbar()

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 13 artists>

# %%
plt.hist(x)
# Out:
# (array([2., 1., 2., 2., 3., 0., 2., 0., 0., 1.]),
#  array([ 2. ,  3.5,  5. ,  6.5,  8. ,  9.5, 11. , 12.5, 14. , 15.5, 17. ]),
#  <BarContainer object of 10 artists>)

# %%
x = [0.66, 0.25, 0.09]
plt.pie(x, labels = ['2/3', '1/5', 'others'])
plt.legend()

# %%
x = [0.66, 0.25, 0.09]
plt.pie(x, labels = ['2/3', '1/5', 'others'], explode = [0.0, 0.2, 0])
plt.legend()

# %%
x = np.arange(10)
alpha = (x+1)**2/2
delta = (x+2)**2
omicron = (x+3)**2 * 3

plt.plot(x, alpha, label = "Alpha")
plt.plot(x, delta, label = "Delta")
plt.plot(x, omicron, label = "Omicron")
plt.legend()

# %% [markdown]
# # Practice

# %%
file = '/content/sample_data/california_housing_train.csv'
df = pd.read_csv(file)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
# play with this dataset using the plots we learned so far

# %%
#Histogram of Median House Values


df['median_house_value'].plot(kind='hist', bins=50, edgecolor='black', figsize=(10,6))
plt.title('Distribution of Median House Value')
plt.xlabel('Median House Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#Scatter Plot: Income vs. House Value
plt.figure(figsize=(10,6))
plt.scatter(df['median_income'], df['median_house_value'], alpha=0.3, c='teal')
plt.title('Median Income vs. Median House Value')
plt.xlabel('Median Income')
plt.ylabel('Median House Value')
plt.grid(True)
plt.show()
